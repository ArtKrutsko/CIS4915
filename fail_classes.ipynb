# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
file_path = 'message.txt'

# Read the file into a pandas DataFrame
df = pd.read_csv(file_path, delim_whitespace=True)
df = df.sort_values(by='Total_Students', ascending=False)

# Display the DataFrame
display(df)
'''
785 	CHM	2210	18036	3617.0	20.054336 (a lot of data/big fail rate)
5174	STA	2023	26023	3845.0	14.775391 (a lot of data/avg fail rate)
3088	MAC	1147	22004	3337.0	15.165424 (a lot of data/avg fail rate)
4623	PSY	2012	19928	2111.0	10.593135 (a lot of data/low fail rate)
527 	BSC	2010	19358	3235.0	16.711437 (a lot of data/avg fail rate)
1211	ECO	2013	16962	1719.0	10.134418 (less data/avg fail rate)
0   	ACG	2021	13474	2716.0	20.157340 (less data/big fail rate)
3095	MAC	2311	10895	2467.0	22.643414 + 3092	MAC	2281	6831	1260.0	18.445323 (Calc 1)
4   	ACG	3103	2923	762.0	26.069107 (not a lot data/big fail rate)
'''
# Out:
#      SUBJ CRSE_NUMB  Total_Students  Total_Failures  Failure_Rate
# 5174  STA      2023           26023          3845.0     14.775391
# 1760  ENC      1101           25852          2746.0     10.622002
# 3088  MAC      1147           22004          3337.0     15.165424
# 3087  MAC      1105           20680          3255.0     15.739845
# 4623  PSY      2012           19928          2111.0     10.593135
# 527   BSC      2010           19358          3235.0     16.711437
# 785   CHM      2210           18036          3617.0     20.054336
# 529   BSC      2011           17287          1838.0     10.632267
# 1211  ECO      2013           16962          1719.0     10.134418
# 1212  ECO      2023           15671          2139.0     13.649416
# 4514  PHY      2053           15151          2083.0     13.748267
# 2756  ISM      3011           14193          1697.0     11.956598
# 1612  EGN      3000           13640          1656.0     12.140762
# ...
